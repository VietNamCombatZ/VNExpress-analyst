# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %%
DATA_PATH = "../data/"

df = pd.read_csv(DATA_PATH + "vnexpress_clean_data.csv")

print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (1038, 16)
#                                                title  \
# 0     Không khí lễ hội xuân một thế kỷ trước qua ảnh
# 1          Kanye West thừa nhận bị rối loạn tâm thần
# 2          Katy Perry quấn quýt cựu Thủ tướng Canada
# 3  Sỏi to 'bằng nắm tay' trong bàng quang người đ...
# 4                    Cuộc đua phim Việt Tết Bính Ngọ
#
#                                          description                 date  \
# 0  Cảnh người dân tham gia lễ hội đền Hai Bà Trưn...  2026-02-27 00:00:00
# 1  Rapper Kanye West cho biết mắc rối loạn lưỡng ...  2026-01-27 15:04:00
# 2  Katy Perry và bạn trai - cựu Thủ tướng Justin ...  2026-02-11 10:49:00
# 3  TP HCMÔng Ngọc, 69 tuổi, có sỏi bàng quang 10 ...  2026-03-10 08:00:00
# 4  Thị trường phim Việt sôi động với bốn tác phẩm...  2026-02-12 11:21:00
#
#                         category  \
# 0  Sân khấu - Mỹ thuật, Mỹ thuật
# 1              Giới sao, Quốc tế
# 2              Giới sao, Quốc tế
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title             1038 non-null   object
#  1   description       1031 non-null   object
#  2   date              1038 non-null   object
#  3   category          1038 non-null   object
#  4   thumbnail         1011 non-null   object
#  5   content           1038 non-null   object
#  6   author            1038 non-null   object
#  7   tags              1031 non-null   object
#  8   group             1038 non-null   object
#  9   nums_of_comments  1038 non-null   int64
#  10  url               1038 non-null   object
#  11  year              1038 non-null   int64
#  12  month             1038 non-null   int64
#  13  hour              1038 non-null   int64
#  14  title_length      1038 non-null   int64
#  15  content_length    1038 non-null   int64
# dtypes: int64(6), object(10)
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# thumbnail           27
# description          7
# tags                 7
# title                0
# category             0
# date                 0
# content              0
# author               0
# group                0
# nums_of_comments     0
# url                  0
# year                 0
# month                0
# hour                 0
# title_length         0
# content_length       0
# dtype: int64

# %%
plt.figure()

sns.countplot(data=df, x="group")

plt.title("Articles per Group (Clean Data)")

plt.show()

# %%
plt.figure()

sns.histplot(df["content_length"], bins=30)

plt.title("Content Length Distribution (Clean Data)")

plt.show()

# %%
plt.figure()

sns.histplot(df["title_length"], bins=30)

plt.title("Title Length Distribution (Clean Data)")

plt.show()

# %%
plt.figure()

sns.countplot(data=df, x="month")

plt.title("Articles by Month")

plt.show()

# %%
plt.figure()

sns.countplot(data=df, x="hour")

plt.title("Articles by Hour")

plt.show()

# %%
plt.figure()

sns.scatterplot(
    data=df,
    x="content_length",
    y="nums_of_comments",
    hue="group"
)

plt.title("Content Length vs Comments")

plt.show()
